# %%
# !nvidia-smi
# Out:
# Sat Jun 27 10:12:56 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   51C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install -q ultralytics supervision pandas matplotlib seaborn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.4 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 kB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 96.3 MB/s eta 0:00:00:00:010:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-cuda 26.2.0 requires cuda-core==0.3.*, but you have cuda-core 1.0.1 which is incompatible.
# dask-cuda 26.2.0 requires numba-cuda<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# distributed-ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# ucxx-cu12 0.48.0 requires numba-cuda[cu12]<0.23.0,>=0.22.1, but you have numba-cuda 0.30.2 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba-cuda[cu12]<0.23.0,>=0.22.2, but you have numba-cuda 0.30.2 which is incompatible.

# %%
from ultralytics import YOLO
import os
import yaml
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import supervision as sv

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.80 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# Setup complete ✅ (4 CPUs, 31.3 GB RAM, 6960.4/8062.4 GB disk)

# %%
from pathlib import Path
import os

# Cek isi folder input Kaggle
input_path = Path("/kaggle/input")

for path in input_path.glob("*"):
    print(path)
# Out:
# /kaggle/input/datasets
# /kaggle/input/notebooks

# %%
yaml_files = list(Path("/kaggle/input/datasets/gibranariq/final-project/final_project.yolo").rglob("data.yaml"))

print("Found data.yaml:")
for y in yaml_files:
    print(y)
# Out:
# Found data.yaml:
# /kaggle/input/datasets/gibranariq/final-project/final_project.yolo/data.yaml

# %%
DATA_YAML = yaml_files[0]
print(DATA_YAML)
# Out:
# /kaggle/input/datasets/gibranariq/final-project/final_project.yolo/data.yaml

# %%
import yaml

with open(DATA_YAML, "r") as f:
    data_config = yaml.safe_load(f)

data_config
# Out:
# {'train': '../train/images',
#  'val': '../valid/images',
#  'test': '../test/images',
#  'nc': 2,
#  'names': ['awake', 'drowsy'],
#  'roboflow': {'workspace': 'gibran-ariq-n',
#   'project': 'final_project-akkei',
#   'version': 12,
#   'license': 'CC BY 4.0',
#   'url': 'https://universe.roboflow.com/gibran-ariq-n/final_project-akkei/dataset/12'}}

# %%
dataset_root = DATA_YAML.parent

print("Dataset root:", dataset_root)
print("Isi folder:")
for item in dataset_root.iterdir():
    print("-", item.name)
# Out:
# Dataset root: /kaggle/input/datasets/gibranariq/final-project/final_project.yolo
# Isi folder:
# - README.dataset.txt
# - README.roboflow.txt
# - data.yaml
# - valid
# - test
# - train

# %%
splits = ["train", "valid", "test"]

for split in splits:
    img_dir = dataset_root / split / "images"
    label_dir = dataset_root / split / "labels"
    
    n_images = len(list(img_dir.glob("*")))
    n_labels = len(list(label_dir.glob("*.txt")))
    
    print(f"{split}: {n_images} images, {n_labels} labels")
# Out:
# train: 1747 images, 1747 labels
# valid: 401 images, 401 labels
# test: 404 images, 404 labels

# %%
print("Classes :", data_config["names"])
print("Number of classes :", data_config["nc"])
# Out:
# Classes : ['awake', 'drowsy']
# Number of classes : 2

# %%
# %%writefile config.py

class Config:

    # Dataset
    DATA_YAML = "/kaggle/input/datasets/gibranariq/final-project/final_project.yolo/data.yaml"
    
    # Model
    MODEL = "yolo11s.pt"
    IMG_SIZE = 640
    
    # Training
    EPOCHS = 300
    PATIENCE = 50
    BATCH = 16
    WORKERS = 4
    SEED = 42
    DEVICE = 0
    
    # Output
    PROJECT = "drowsiness_detection"
    NAME = "v3"

config = Config()
# Out:
# Writing config.py

# %%
import random
import numpy as np
import torch
from config import config

random.seed(config.SEED)
np.random.seed(config.SEED)
torch.manual_seed(config.SEED)
torch.cuda.manual_seed_all(config.SEED)

# %%
model = YOLO(config.MODEL)

results = model.train(
    data=config.DATA_YAML,
    epochs=config.EPOCHS,
    patience=config.PATIENCE,
    imgsz=config.IMG_SIZE,
    batch=config.BATCH,
    workers=config.WORKERS,
    seed=config.SEED,
    device=config.DEVICE,
    project=config.PROJECT,
    name=config.NAME,
    
    optimizer="AdamW",
    lr0=0.0008,
    lrf=0.01,
    cos_lr=True,

    degrees=5.0,
    shear=2.0,
    perspective=0.0005,
    mosaic=0.5,
    mixup=0.05,
    
    exist_ok=False,
    cache=False
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 108.9MB/s 0.2s1s<0.2s
# Ultralytics 8.4.80 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/kaggle/input/datasets/gibranariq/final-project/final_project.yolo/data.yaml, degrees=5.0, deterministic=True, device=0, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=300, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0008, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.05, mode=train, model=yolo11s.pt, momentum=0.937, mosaic=0.5, multi_scale=0.0, name=v3, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=50, perspective=0.0005, plots=True, pose=12.0, pretrained=True, profile=False, project=drowsiness_detection, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/drowsiness_detection/v3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=2.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.1MB/s 0.0s
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    820182  ultralytics.nn.modules.head.Detect           [2, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,428,566 parameters, 9,428,550 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 71.2MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.1±0.1 ms, read: 6.0±1.8 MB/s, size: 41.2 KB)
# train: Scanning /kaggle/input/datasets/gibranariq/final-project/final_project.yolo/train/labels... 1747 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1747/1747 223.8it/s 7.8s0.0s
# WARNING ⚠️ train: Cache directory /kaggle/input/datasets/gibranariq/final-project/final_project.yolo/train is not writable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5.3±1.5 MB/s, size: 31.7 KB)
# val: Scanning /kaggle/input/datasets/gibranariq/final-project/final_project.yolo/valid/labels... 401 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 401/401 206.8it/s 1.9s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/gibranariq/final-project/final_project.yolo/valid is not writable, cache not saved.
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 11, len(boxes) = 409. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: AdamW(lr=0.0008, momentum=0.937) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Plotting labels to /kaggle/working/runs/detect/drowsiness_detection/v3/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/drowsiness_detection/v3
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/300      4.08G      1.485      1.644      1.635          6        640: 100% ━━━━━━━━━━━━ 110/110 2.2it/s 49.4s0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 10.0s.3s
#                    all        401        409      0.535      0.713      0.637      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/300      5.29G      1.405       1.21      1.569          7        640: 100% ━━━━━━━━━━━━ 110/110 3.4it/s 32.2s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s0.3s
#                    all        401        409      0.475      0.589      0.437      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/300      5.29G      1.387       1.25      1.564          5        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.589      0.561      0.553      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/300      5.29G      1.314      1.083      1.516          4        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409       0.44       0.57      0.447      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/300      5.29G      1.297      1.107      1.501          4        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.706      0.708      0.715      0.399
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/300      5.29G      1.305      1.071      1.481          3        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.482      0.731      0.567      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/300      5.29G       1.28      1.068      1.464          6        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.7s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.629      0.774      0.707      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/300      5.29G      1.262      1.003      1.456          3        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.6s0.3s
#                    all        401        409      0.758       0.71       0.82      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/300      5.29G      1.259     0.9688      1.455          6        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.828      0.861      0.873      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/300      5.29G      1.259      0.951      1.445          8        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.644      0.841       0.81        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/300      5.29G      1.229     0.9448      1.422          6        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s0.3s
#                    all        401        409      0.749      0.735        0.8      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/300      5.29G      1.201     0.8931      1.418          4        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.851       0.81      0.872      0.499
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/300      5.29G      1.221     0.9106       1.43          4        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s0.3s
#                    all        401        409      0.751      0.773      0.836      0.443
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/300      5.29G      1.233      0.904      1.426          6        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.6it/s 3.6s0.3s
#                    all        401        409       0.86      0.857      0.904      0.502
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/300      5.29G       1.21      0.878      1.403          3        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.818      0.885      0.912       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/300      5.29G      1.176     0.8543      1.391          3        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.542      0.757      0.808      0.418
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/300      5.29G      1.156     0.8486      1.381          5        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.7s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        
0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/300      5.29G     0.9086     0.5623      1.189          6        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.898      0.854      0.919      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/300      5.29G     0.8837     0.5515      1.181          5        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409       0.89      0.881      0.924       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/300      5.29G     0.8889     0.5357       1.19          5        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.863      0.823      0.908      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     101/300      5.29G     0.9026     0.5651      1.195          5        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.839      0.833      0.902      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     102/300      5.29G     0.9031     0.5511      1.194          3        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 31.0s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.923      0.902      0.933       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     103/300      5.29G     0.8938     0.5668      1.187          7        640: 100% ━━━━━━━━━━━━ 110/110 3.5it/s 31.0s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.852      0.876      0.915      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     104/300      5.29G     0.8604     0.5234      1.169          6        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.863      0.907      0.917      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     105/300      5.29G      0.873     0.5354      1.173          3        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.894      0.907      0.927      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     106/300      5.29G     0.9039     0.5523        1.2          4        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.925      0.859       0.93      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     107/300      5.29G     0.8876      0.543      1.192          4        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.904      0.895      0.937       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     108/300      5.29G     0.8992     0.5338      1.183          4        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.6s0.3s
#                    all        401        409      0.911      0.862      0.926      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     109/300      5.29G     0.8815     0.5347      1.181          4        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.926      0.847      0.927      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     110/300      5.29G     0.8854     0.5565      1.176          7        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.6s0.3s
#                    all        401        409      0.911      0.789      0.908      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     111/300      5.29G      0.887     0.5348      1.183          7        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.944       0.84      0.925      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     112/300      5.29G      0.869     0.5353      1.174          5        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.923       0.81      0.923      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     113/300      5.29G     0.8953     0.5307       1.19          4        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.893      0.905      0.934      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     114/300      5.29G     0.8788     0.5273      1.175          5        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.888      0.875      0.923      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     115/300      5.29G     0.8773     0.5491      1.179          7        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.9s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.917      0.907      0.933       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     116/300      5.29G     0.8851     0.5465       1.18          6        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.7s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.877      0.908       0.93      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     117/300      5.29G     0.8788     0.5259      1.175          5        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.923      0.914      0.935      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     118/300      5.29G     0.8842     0.5358      1.192          3        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.856      0.889      0.914      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     119/300      5.29G     0.8573     0.5137      1.162          4        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.877      0.905      0.927      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     120/300      5.29G     0.8465     0.5353      1.163          3        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.7s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.822      0.876      0.927      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     121/300      5.29G     0.8584     0.5127      1.171          7        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.909      0.862       0.92      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     122/300      5.29G     0.8397     0.5105      1.153          6        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.8s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.7it/s 3.5s0.3s
#                    all        401        409      0.892      0.899       0.94      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     123/300      5.29G     0.8535     0.5238      1.158          6        640: 100% ━━━━━━━━━━━━ 110/110 3.6it/s 30.6s0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.8it/s 3.5s0.3s
#                    all        401        409      0.919      0.902      0.941      0.551
# EarlyStopping: Training stopped early as no improvement observed in last 50 epochs. Best results observed at epoch 73, best model saved as best.pt.
# To update EarlyStopping(patience=50) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 123 epochs completed in 1.199 hours.
# Optimizer stripped from /kaggle/working/runs/detect/drowsiness_detection/v3/weights/last.pt, 19.2MB
# Optimizer stripped from /kaggle/working/runs/detect/drowsiness_detection/v3/weights/best.pt, 19.2MB
#
# Validating /kaggle/working/runs/detect/drowsiness_detection/v3/weights/best.pt...
# Ultralytics 8.4.80 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO11s summary (fused): 101 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 3.0it/s 4.3s0.3s
#                    all        401        409      0.902      0.893      0.929      0.572
#                  awake        208        208       0.89      0.938      0.965      0.588
#                 drowsy        193        201      0.914      0.847      0.892      0.557
# Speed: 0.2ms preprocess, 5.1ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to /kaggle/working/runs/detect/drowsiness_detection/v3

# %%
from pathlib import Path

train_path = Path(results.save_dir)
print(train_path)

best_model_path = train_path / "weights" / "best.pt"
last_model_path = train_path / "weights" / "last.pt"

print("Best:", best_model_path)
print("Last:", last_model_path)
# Out:
# /kaggle/working/runs/detect/drowsiness_detection/v3
# Best: /kaggle/working/runs/detect/drowsiness_detection/v3/weights/best.pt
# Last: /kaggle/working/runs/detect/drowsiness_detection/v3/weights/last.pt

# %%
import pandas as pd
from pathlib import Path

run_path = Path("/kaggle/working/runs/detect/drowsiness_detection/v3")
results_df = pd.read_csv(run_path / "results.csv")
results_df.tail()
# Out:
#      epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 118    119  4176.51         0.85731         0.51365         1.16238
# 119    120  4211.27         0.84654         0.53528         1.16259
# 120    121  4246.19         0.85838         0.51271         1.17058
# 121    122  4281.08         0.83965         0.51054         1.15280
# 122    123  4315.69         0.85346         0.52382         1.15790
#
#      metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 118               0.87672            0.90480           0.92657
# 119               0.82163            0.87632           0.92732
# 120               0.90860            0.86223           0.91968
# 121               0.89232            0.89874           0.94007
# 122               0.91867            0.90210           0.94055
#
#      metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 118              0.54508       1.42943       0.62472       1.54539  0.000534
# 119              0.55746       1.35576       0.71789       1.51785  0.000530
# 120              0.54443       1.42364       0.65875       1.54662  0.000526
# 121              0.54827       1.41027       0.60947       1.55797  0.000522
# 122              0.55098       1.46713       0.57276       1.55543  0.000518
#
#        lr/pg1    lr/pg2
# 118  0.000534  0.000534
# 119  0.000530  0.000530
# 120  0.000526  0.000526
# 121  0.000522  0.000522
# 122  0.000518  0.000518

# %%
from ultralytics import YOLO

best_model = YOLO(best_model_path)

metrics = best_model.val(
    data=config.DATA_YAML,
    imgsz=config.IMG_SIZE,
    batch=config.BATCH,
    device=config.DEVICE,
    split="test"
)
# Out:
# Ultralytics 8.4.80 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO11s summary (fused): 101 layers, 9,413,574 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.7 ms, read: 6.0±3.0 MB/s, size: 36.8 KB)
# val: Scanning /kaggle/input/datasets/gibranariq/final-project/final_project.yolo/test/labels... 404 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 404/404 217.8it/s 1.9s0.1s
# WARNING ⚠️ val: Cache directory /kaggle/input/datasets/gibranariq/final-project/final_project.yolo/test is not writable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 4.0it/s 6.6s0.2s
#                    all        404        404      0.842       0.89      0.929      0.597
#                  awake        213        213      0.815      0.972      0.936      0.596
#                 drowsy        191        191       0.87      0.807      0.921      0.597
# Speed: 1.6ms preprocess, 11.0ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val

# %%
from pathlib import Path

val_path = Path("/kaggle/working/runs/detect/val")
list(val_path.iterdir())
# Out:
# [PosixPath('/kaggle/working/runs/detect/val/BoxP_curve.png'),
#  PosixPath('/kaggle/working/runs/detect/val/confusion_matrix_normalized.png'),
#  PosixPath('/kaggle/working/runs/detect/val/val_batch1_labels.jpg'),
#  PosixPath('/kaggle/working/runs/detect/val/val_batch2_pred.jpg'),
#  PosixPath('/kaggle/working/runs/detect/val/val_batch2_labels.jpg'),
#  PosixPath('/kaggle/working/runs/detect/val/confusion_matrix.png'),
#  PosixPath('/kaggle/working/runs/detect/val/val_batch0_pred.jpg'),
#  PosixPath('/kaggle/working/runs/detect/val/BoxF1_curve.png'),
#  PosixPath('/kaggle/working/runs/detect/val/val_batch1_pred.jpg'),
#  PosixPath('/kaggle/working/runs/detect/val/val_batch0_labels.jpg'),
#  PosixPath('/kaggle/working/runs/detect/val/BoxPR_curve.png'),
#  PosixPath('/kaggle/working/runs/detect/val/BoxR_curve.png')]

# %%
from pathlib import Path

train_path = Path(results.save_dir)
best_model = train_path / "weights" / "best.pt"

print(best_model)
# Out:
# /kaggle/working/runs/detect/drowsiness_detection/v3/weights/best.pt

# %%
from IPython.display import Image, display

display(Image(filename=train_path / "results.png"))
display(Image(filename=train_path / "confusion_matrix.png"))

# %%
from datetime import datetime
import pandas as pd
import torch
import ultralytics

report_path = train_path / "experiment_report.txt"
results_df = pd.read_csv(train_path / "results.csv")

device_name = torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU"
amp_enabled = torch.cuda.is_available()

precision = metrics.box.mp
recall = metrics.box.mr
f1_score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

with open(report_path, "w") as f:
    f.write("===== Experiment Report =====\n")
    f.write(f"Date              : {datetime.now()}\n")
    f.write(f"Experiment Name   : {config.NAME}\n")
    f.write(f"Train Output Path : {train_path}\n\n")

    f.write("===== Dataset =====\n")
    f.write(f"Data YAML         : {config.DATA_YAML}\n\n")

    f.write("===== Model =====\n")
    f.write(f"Model Weight      : {config.MODEL}\n")
    f.write(f"Image Size        : {config.IMG_SIZE}\n")
    f.write(f"Best Model Path   : {best_model_path}\n")
    f.write(f"Last Model Path   : {last_model_path}\n\n")

    f.write("===== Training Parameters =====\n")
    f.write(f"Epochs            : {config.EPOCHS}\n")
    f.write(f"Patience          : {config.PATIENCE}\n")
    f.write(f"Batch Size        : {config.BATCH}\n")
    f.write(f"Workers           : {config.WORKERS}\n")
    f.write(f"Seed              : {config.SEED}\n")
    f.write(f"Device            : {config.DEVICE} ({device_name})\n")
    f.write(f"AMP               : {amp_enabled}\n")
    f.write(f"Ultralytics Ver   : {ultralytics.__version__}\n")
    f.write(f"PyTorch Ver       : {torch.__version__}\n\n")

    f.write("===== Best Validation Metrics from Training =====\n")
    
    if "fitness" in results_df.columns:
        best_idx = results_df["fitness"].idxmax()
    else:
        best_idx = results_df["metrics/mAP50-95(B)"].idxmax()
    
    best_row = results_df.iloc[best_idx]
    
    f.write(f"Best Epoch                  : {int(best_row['epoch'])}\n\n")
    
    for col in results_df.columns:
        f.write(f"{col:<30}: {best_row[col]}\n")

    f.write("===== Final Test Evaluation =====\n")
    f.write(f"Precision (Box)   : {precision:.4f}\n")
    f.write(f"Recall (Box)      : {recall:.4f}\n")
    f.write(f"F1 Score          : {f1_score:.4f}\n")
    f.write(f"mAP50             : {metrics.box.map50:.4f}\n")
    f.write(f"mAP50-95          : {metrics.box.map:.4f}\n\n")

    f.write("===== Test Evaluation per Class =====\n")
    for i, name in metrics.names.items():
        class_precision = metrics.box.p[i]
        class_recall = metrics.box.r[i]
        class_f1 = (
            2 * class_precision * class_recall / (class_precision + class_recall)
            if (class_precision + class_recall) > 0
            else 0
        )

        f.write(f"\n{name}\n")
        f.write(f"  Precision       : {class_precision:.4f}\n")
        f.write(f"  Recall          : {class_recall:.4f}\n")
        f.write(f"  F1 Score        : {class_f1:.4f}\n")
        f.write(f"  mAP50           : {metrics.box.ap50[i]:.4f}\n")
        f.write(f"  mAP50-95        : {metrics.box.ap[i]:.4f}\n")

    f.write("\n===== Output Files =====\n")
    f.write(f"Results CSV       : {train_path / 'results.csv'}\n")
    f.write(f"Results Plot      : {train_path / 'results.png'}\n")
    f.write(f"Confusion Matrix  : {train_path / 'confusion_matrix.png'}\n")
    f.write(f"PR Curve          : {train_path / 'PR_curve.png'}\n")

print(f"Report saved to: {report_path}")
# Out:
# Report saved to: /kaggle/working/runs/detect/drowsiness_detection/v3/experiment_report.txt

# %%
print(report_path.read_text())
# Out:
# ===== Experiment Report =====
# Date              : 2026-06-27 11:32:06.506790
# Experiment Name   : v3
# Train Output Path : /kaggle/working/runs/detect/drowsiness_detection/v3
#
# ===== Dataset =====
# Data YAML         : /kaggle/input/datasets/gibranariq/final-project/final_project.yolo/data.yaml
#
# ===== Model =====
# Model Weight      : yolo11s.pt
# Image Size        : 640
# Best Model Path   : /kaggle/working/runs/detect/drowsiness_detection/v3/weights/best.pt
# Last Model Path   : /kaggle/working/runs/detect/drowsiness_detection/v3/weights/last.pt
#
# ===== Training Parameters =====
# Epochs            : 300
# Patience          : 50
# Batch Size        : 16
# Workers           : 4
# Seed              : 42
# Device            : 0 (Tesla T4)
# AMP               : True
# Ultralytics Ver   : 8.4.80
# PyTorch Ver       : 2.10.0+cu128
#
# ===== Best Validation Metrics from Training =====
# Best Epoch                  : 73
#
# epoch                         : 73.0
# time                          : 2572.55
# train/box_loss                : 0.96283
# train/cls_loss                : 0.58666
# train/dfl_loss                : 1.22549
# metrics/precision(B)          : 0.90256
# metrics/recall(B)             : 0.89261
# metrics/mAP50(B)              : 0.92881
# metrics/mAP50-95(B)           : 0.57255
# val/box_loss                  : 1.3741
# val/cls_loss                  : 0.6187
# val/dfl_loss                  : 1.43342
# lr/pg0                        : 0.000692672
# lr/pg1                        : 0.000692672
# lr/pg2                        : 0.000692672
# ===== Final Test Evaluation =====
# Precision (Box)   : 0.8424
# Recall (Box)      : 0.8895
# F1 Score          : 0.8653
# mAP50             : 0.9288
# mAP50-95          : 0.5967
#
# ===== Test Evaluation per Class =====
#
# awake
#   Precision       : 0.8147
#   Recall          : 0.9718
#   F1 Score        : 0.8863
#   mAP50           : 0.9361
#   mAP50-95        : 0.5961
#
# drowsy
#   Precision       : 0.8702
#   Recall          : 0.8072
#   F1 Score        : 0.8375
#   mAP50           : 0.9215
#   mAP50-95        : 0.5973
#
# ===== Output Files =====
# Results CSV       : /kaggle/working/runs/detect/drowsiness_detection/v3/results.csv
# Results Plot      : /kaggle/working/runs/detect/drowsiness_detection/v3/results.png
# Confusion Matrix  : /kaggle/working/runs/detect/drowsiness_detection/v3/confusion_matrix.png
# PR Curve          : /kaggle/working/runs/detect/drowsiness_detection/v3/PR_curve.png
